# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
from io import BytesIO
import os

# %%
img = Image.open('trui.png')
imgGray = img.convert('LA')
imgplot = plt.imshow(imgGray)
plt.show()
print(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x256 at 0x7FA036229910>

# %%
img = mpimg.imread('cameraman.jpg')
# img = Image.open('cameraman.jpg')
#imgGray = img.convert('LA')
imgplot = plt.imshow(img)
plt.show()
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
salt_value = 40
noise = np.random.randint(salt_value+1, size=(512, 512))
#---------- Pepper ----------#

indexe = np.where(noise == 0)

A = indexe[0]
B = indexe[1]

img[A,B,:] = 0

#---------- Salt ----------#

indexe = np.where(noise == salt_value)

A = indexe[0]
B = indexe[1]

img[A,B,:] = 255
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-653944c436e0> in <module>()
#       8 B = indexe[1]
#       9
# ---> 10 img[A,B,:] = 0
#      11
#      12 #---------- Salt ----------#
#
# ValueError: assignment destination is read-only
